# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv("data/training_data_utf8.csv")
# Out:
# /usr/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/loherzberger/Projects/ML/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.shape
# Out:
# (44366, 18)

# %%
data.head()
# Out:
#      id  price_per_m2 transaction_ym  plot_area  plot_share  \
# 0  7671    224.351484        2013-12       4279         1.0
# 1  7672    357.995227        2013-12        838         1.0
# 2  7673    636.474908        2013-12        817         1.0
# 3  7674    906.095552        2013-12        607         1.0
# 4  7675    167.941498        2013-12      11897         1.0
#
#             property_type           cadastral     district contract_type  \
# 0          Betriebsobjekt              Kagran   Donaustadt   Kaufvertrag
# 1           Abbruchobjekt             Liesing      Liesing   Kaufvertrag
# 2  Ein-, Zweifamilienhaus         Atzgersdorf      Liesing   Kaufvertrag
# 3  Ein-, Zweifamilienhaus           Ottakring    Ottakring   Kaufvertrag
# 4                unbebaut  Groß Jedlersdorf I  Floridsdorf   Kaufvertrag
#
#   land_use  land_use_share protection_zone building_ban building_height  \
# 0       GB            1.00              No           No             NaN
# 1        W            1.00              No           No            10.5
# 2       GB            1.00              No           No             3.5
# 3        W            1.00              No           No             7.5
# 4        W            0.19              No           No             NaN
#
#    building_floors  building_year  longitude   latitude
# 0              1.0         1990.0  16.464163  48.259071
# 1              2.0            NaN  16.275103  48.133264
# 2              2.0            NaN  16.296926  48.145348
# 3              2.0            NaN  16.290968  48.217580
# 4              NaN            NaN  16.418471  48.288753

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44366 entries, 0 to 44365
# Data columns (total 18 columns):
# id                 44366 non-null int64
# price_per_m2       44366 non-null float64
# transaction_ym     44366 non-null object
# plot_area          44366 non-null int64
# plot_share         44366 non-null float64
# property_type      44366 non-null object
# cadastral          44366 non-null object
# district           44294 non-null object
# contract_type      44366 non-null object
# land_use           44260 non-null object
# land_use_share     44320 non-null float64
# protection_zone    44366 non-null object
# building_ban       44366 non-null object
# building_height    7800 non-null object
# building_floors    18422 non-null float64
# building_year      14739 non-null float64
# longitude          32465 non-null float64
# latitude           32465 non-null float64
# dtypes: float64(7), int64(2), object(9)
# memory usage: 6.1+ MB

# %%
#describe numerical values
data.describe()
# Out:
#                  id   price_per_m2     plot_area    plot_share  \
# count  44366.000000   44366.000000  4.436600e+04  44366.000000
# mean   29853.500000     789.062369  1.880226e+03      0.959631
# std    12807.505358    2276.246856  1.064498e+04      0.163726
# min     7671.000000       0.161937  1.000000e+00      0.000260
# 25%    18762.250000     181.682084  4.120000e+02      1.000000
# 50%    29853.500000     354.343664  5.810000e+02      1.000000
# 75%    40944.750000     726.728429  1.035000e+03      1.000000
# max    52036.000000  197628.458498  1.187781e+06      1.000000
#
#        land_use_share  building_floors  building_year     longitude  \
# count    44320.000000     18422.000000   14739.000000  32465.000000
# mean         0.956965         2.063402    1913.283737     16.363182
# std          0.144435         1.902943      37.464120      0.074558
# min          0.000000         0.000000    1800.000000     15.605753
# 25%          1.000000         0.000000    1894.000000     16.310912
# 50%          1.000000         2.000000    1900.000000     16.352831
# 75%          1.000000         4.000000    1940.000000     16.407386
# max          1.000000        12.000000    2017.000000     16.572405
#
#            latitude
# count  32465.000000
# mean      48.207192
# std        0.039031
# min       47.850748
# 25%       48.179708
# 50%       48.208886
# 75%       48.230576
# max       48.314311

# %%
#describe categorical values
data.describe(include="O")
# Out:
#        transaction_ym property_type cadastral    district contract_type  \
# count           44366         44366     44366       44294         44366
# unique            324            16        88          23            11
# top           1988-12      unbebaut    Eßling  Donaustadt   Kaufvertrag
# freq              296         15345      2270        8476         38853
#
#        land_use protection_zone building_ban building_height
# count     44260           44366        44366            7800
# unique       56               2            2              97
# top      WI/GBI              No           No             6.5
# freq      12099           43306        43857            2763

# %%
#data = data[data.price_per_m2 < 60000]
data.plot(x="transaction_ym", y="price_per_m2")

# %%
#data = data[data.longitude > 16.0]
#data = data[data.longitude < 16.55]

# %%
#data = data[data.latitude > 48.0]

# %%
data.plot(kind="scatter", x="longitude", y="latitude", alpha=0.1)

# %%
data.describe()
# Out:
#                  id   price_per_m2     plot_area    plot_share  \
# count  44366.000000   44366.000000  4.436600e+04  44366.000000
# mean   29853.500000     789.062369  1.880226e+03      0.959631
# std    12807.505358    2276.246856  1.064498e+04      0.163726
# min     7671.000000       0.161937  1.000000e+00      0.000260
# 25%    18762.250000     181.682084  4.120000e+02      1.000000
# 50%    29853.500000     354.343664  5.810000e+02      1.000000
# 75%    40944.750000     726.728429  1.035000e+03      1.000000
# max    52036.000000  197628.458498  1.187781e+06      1.000000
#
#        land_use_share  building_floors  building_year     longitude  \
# count    44320.000000     18422.000000   14739.000000  32465.000000
# mean         0.956965         2.063402    1913.283737     16.363182
# std          0.144435         1.902943      37.464120      0.074558
# min          0.000000         0.000000    1800.000000     15.605753
# 25%          1.000000         0.000000    1894.000000     16.310912
# 50%          1.000000         2.000000    1900.000000     16.352831
# 75%          1.000000         4.000000    1940.000000     16.407386
# max          1.000000        12.000000    2017.000000     16.572405
#
#            latitude
# count  32465.000000
# mean      48.207192
# std        0.039031
# min       47.850748
# 25%       48.179708
# 50%       48.208886
# 75%       48.230576
# max       48.314311

# %%
data["cadastral"].value_counts()
# Out:
# Eßling                        2270
# Aspern                        1984
# Kagran                        1829
# Leopoldstadt                  1292
# Ottakring                     1290
# Inzersdorf                    1277
# Mauer                         1268
# Leopoldau                     1218
# Ober St.Veit                  1164
# Landstraße                    1104
# Stammersdorf                  1042
# Simmering                     1005
# Brigittenau                    893
# Favoriten                      870
# Margarethen                    863
# Kaiserebersdorf                840
# Dornbach                       792
# Stadlau                        790
# Neubau                         786
# Hadersdorf                     778
# Alsergrund                     776
# Auhof                          756
# Meidling                       754
# Hütteldorf                     701
# Atzgersdorf                    671
# Breitenlee                     669
# Hernals                        644
# Strebersdorf                   625
# Groß Jedlersdorf I             606
# Mariahilf                      576
#                               ...
# Groß Jedlersdorf II            241
# Schwarze Lackenau              237
# Obersievering                  224
# Hietzing                       224
# Nußdorf                        220
# Jedlesee                       198
# Gersthof                       196
# Neuwaldegg                     177
# Kaisermühlen                   166
# Unter St.Veit                  161
# Neustift am Walde              154
# Unterbaumgarten                153
# Kalksburg                      148
# Floridsdorf                    148
# Weidlingau                     129
# Sechshaus                      119
# Unterdöbling                   103
# Oberbaumgarten                 103
# Rothneusiedl                    88
# Kahlenbergerdorf                83
# Gaudenzdorf                     81
# Salmannsdorf                    76
# Unterlaa                        73
# Hacking                         67
# Weinhaus                        41
# Albern                          36
# Josefsdorf                      14
# Schönbrunn                       3
# Kaiserebersdorf Herrschaft       2
# Rosenberg                        2
# Name: cadastral, Length: 88, dtype: int64

# %%
data["district"].value_counts()
# Out:
# Donaustadt      8476
# Liesing         4903
# Floridsdorf     4840
# Hietzing        3015
# Penzing         2555
# Favoriten       2356
# Döbling         2091
# Simmering       1828
# Hernals         1609
# Ottakring       1547
# Meidling        1423
# Leopoldstadt    1292
# Währing         1145
# Landstraße      1106
# Fünfhaus         991
# Brigittenau      868
# Margareten       856
# Neubau           785
# Alsergrund       778
# Mariahilf        572
# Josefstadt       442
# Innere Stadt     427
# Wieden           389
# Name: district, dtype: int64

# %%
data["contract_type"].value_counts()
# Out:
# Kaufvertrag            38853
# GRA Beschluss           1549
# MA 64-Bescheid          1421
# Magistratsbeschluss     1153
# GR Beschluss            1047
# Versteigerung            179
# Tauschvertrag            124
# Enteig. /Einl.            22
# Sonstiges                 15
# KV-Entwurf                 2
# Baurechtsvertrag           1
# Name: contract_type, dtype: int64

# %%
corrmat = data.corr()
sns.set_color_codes("pastel")
f, ax = plt.subplots(figsize=(12,8))
cmap = sns.diverging_palette(240, 10, as_cmap=True)
sns.heatmap(corrmat, vmin=-1, square=True, cmap=cmap)

# %%
corrmat["price_per_m2"].sort_values(ascending=False)
# Out:
# price_per_m2       1.000000
# building_floors    0.385326
# plot_share         0.002082
# latitude          -0.011045
# plot_area         -0.028618
# longitude         -0.038409
# land_use_share    -0.050230
# building_year     -0.051976
# id                -0.133134
# Name: price_per_m2, dtype: float64

# %%
from pandas.tools.plotting import scatter_matrix

attributes = ["price_per_m2", "building_floors", "plot_share", "plot_area", "building_year"]
scatter_matrix(data[attributes], figsize=(12, 8))
# Out:
# /home/loherzberger/Projects/ML/venv/lib/python3.6/site-packages/ipykernel_launcher.py:4: FutureWarning: 'pandas.tools.plotting.scatter_matrix' is deprecated, import 'pandas.plotting.scatter_matrix' instead.
#   after removing the cwd from sys.path.
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fade4d213c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fade4d469e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fade4cf90b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fade4c9e748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fade4cc6dd8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fade4cc6e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fade4c20b38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fade4c51208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fade4bfa898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fade4ba4f28>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fade4bd35f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fade2b30c88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fade2ae3358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fade2b099e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fade2abc0b8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fade2a64748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fade2a8add8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fade2a3e4a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fade29a8b38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fade2957208>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fade297f898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fade2928f98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fade28d95c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fade2901c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fade28b1320>]],
#       dtype=object)
